# %%
import os

# %%
os.listdir()
# Out:
# ['some_pandas.ipynb',
#  'supermarkets.json',
#  'supermarkets.csv',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.xlsx',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt']

# %%
import pandas
dir(pandas)
# Out:
# ['Categorical',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'ExcelFile',
#  'ExcelWriter',
#  'Expr',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int64Index',
#  'Interval',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Period',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseSeries',
#  'Term',
#  'TimeGrouper',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt64Index',
#  'WidePanel',
#  '_DeprecatedModule',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_hashtable',
#  '_lib',
#  '_libs',
#  '_np_version_under1p10',
#  '_np_version_under1p11',
#  '_np_version_under1p12',
#  '_np_version_under1p13',
#  '_np_version_under1p14',
#  '_np_version_under1p15',
#  '_tslib',
#  '_version',
#  'api',
# ...

# %%
df1 = pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1.shape
# Out:
# (6, 7)

# %%
df1.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df1.shape
# Out:
# (6, 7)

# %%
df2 = pandas.read_json("supermarkets.json")
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df2.shape
# Out:
# (6, 7)

# %%
df2.set_index("ID")
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df3 = pandas.read_excel("supermarkets.xlsx", sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv("supermarkets-semi-colons.txt", sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6 = pandas.read_csv("https://pythonhow.com/supermarkets.csv")
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7 = df6.set_index("Address")
df7
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7.shape
# Out:
# (6, 6)

# %%
df7.loc["735 Dolores St":"332 Hill St", "ID":"Name"]
# Out:
#                 ID           City             State Country         Name
# Address
# 735 Dolores St   2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      3  San Francisco  California 94114     USA  Super River

# %%
df7.iloc[5,:]
# Out:
# ID                       6
# City         San Francisco
# State             CA 94114
# Country                USA
# Name            Richvalley
# Employees               20
# Name: 551 Alvarado St, dtype: object

# %%
df7.iloc[1:4,1:4]
# Out:
#                          City             State Country
# Address
# 735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St     San Francisco  California 94114     USA
# 3995 23rd St    San Francisco          CA 94114     USA

# %%
df7
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7.drop("3666 21st St",0)
# Out:
#                  ID           City             State Country         Name  \
# Address
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7.drop(df7.index[0:3])
# Out:
#                  ID           City       State Country        Name  Employees
# Address
# 3995 23rd St      4  San Francisco    CA 94114     USA  Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA     Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA  Richvalley         20

# %%
df7
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7.drop("City", 1)
# Out:
#                  ID             State Country         Name  Employees
# Address
# 3666 21st St      1          CA 94114     USA      Madeira          8
# 735 Dolores St    2          CA 94119     USA  Bready Shop         15
# 332 Hill St       3  California 94114     USA  Super River         25
# 3995 23rd St      4          CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5        California     USA      Sanchez         12
# 551 Alvarado St   6          CA 94114     USA   Richvalley         20

# %%
df7["Continent"] = df7["Country"] + " North America"

# %%
df7
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees          Continent
# Address
# 3666 21st St             8  USA North America
# 735 Dolores St          15  USA North America
# 332 Hill St             25  USA North America
# 3995 23rd St            10  USA North America
# 1056 Sanchez St         12  USA North America
# 551 Alvarado St         20  USA North America

# %%
df7.shape
# Out:
# (6, 7)

# %%
df7["Continent Short"] = df7.shape[0] * ["NA"]

# %%
df7
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees          Continent Continent Short
# Address
# 3666 21st St             8  USA North America              NA
# 735 Dolores St          15  USA North America              NA
# 332 Hill St             25  USA North America              NA
# 3995 23rd St            10  USA North America              NA
# 1056 Sanchez St         12  USA North America              NA
# ...

# %%
df7_t=df7.T

# %%
df7_t
# Out:
# Address               3666 21st St     735 Dolores St        332 Hill St  \
# ID                               1                  2                  3
# City                 San Francisco      San Francisco      San Francisco
# State                     CA 94114           CA 94119   California 94114
# Country                        USA                USA                USA
# Name                       Madeira        Bready Shop        Super River
# Employees                        8                 15                 25
# Continent        USA North America  USA North America  USA North America
# Continent Short                 NA                 NA                 NA
#
# Address               3995 23rd St    1056 Sanchez St    551 Alvarado St
# ID                               4                  5                  6
# City                 San Francisco      San Francisco      San Francisco
# State                     CA 94114         California           CA 94114
# ...

# %%
df7_t["My address"] = [7,"My city", "My state", "My country", "My name", 10, "My continent", "My continent short"]

# %%
df7_t
# Out:
# Address               3666 21st St     735 Dolores St        332 Hill St  \
# ID                               1                  2                  3
# City                 San Francisco      San Francisco      San Francisco
# State                     CA 94114           CA 94119   California 94114
# Country                        USA                USA                USA
# Name                       Madeira        Bready Shop        Super River
# Employees                        8                 15                 25
# Continent        USA North America  USA North America  USA North America
# Continent Short                 NA                 NA                 NA
#
# Address               3995 23rd St    1056 Sanchez St    551 Alvarado St  \
# ID                               4                  5                  6
# City                 San Francisco      San Francisco      San Francisco
# State                     CA 94114         California           CA 94114
# ...

# %%
df7=df7_t.T
df7
# Out:
#                 ID           City             State     Country         Name  \
# Address
# 3666 21st St     1  San Francisco          CA 94114         USA      Madeira
# 735 Dolores St   2  San Francisco          CA 94119         USA  Bready Shop
# 332 Hill St      3  San Francisco  California 94114         USA  Super River
# 3995 23rd St     4  San Francisco          CA 94114         USA   Ben's Shop
# 1056 Sanchez St  5  San Francisco        California         USA      Sanchez
# 551 Alvarado St  6  San Francisco          CA 94114         USA   Richvalley
# My address       7        My city          My state  My country      My name
#
#                 Employees          Continent     Continent Short
# Address
# 3666 21st St            8  USA North America                  NA
# 735 Dolores St         15  USA North America                  NA
# 332 Hill St            25  USA North America                  NA
# 3995 23rd St           10  USA North America                  NA
# ...
